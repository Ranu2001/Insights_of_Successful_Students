# %%
# Current working directory:
import os 
os.getcwd()
# Out:
# 'C:\\Users\\ranub'

# %%
os.chdir("C:\\Users\\ranub\\Downloads")

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_excel("data_analystdata.xlsx")

# %%
data
# Out:
#      First Name           Email ID  Quantity  \
# 0        ANIKET     aniket@xyz.com         1
# 1     Dhanshree  dhanshree@xyz.com         1
# 2        Dhiraj     dhiraj@xyz.com         1
# 3         Pooja      pooja@xyz.com         1
# 4        Aayush     aayush@xyz.com         1
# ...         ...                ...       ...
# 4889        NaN                NaN         1
# 4890        NaN                NaN         1
# 4891        NaN                NaN         1
# 4892        NaN                NaN         1
# 4893        NaN                NaN         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...                                 ...             ...
# 4889   The SDLC & their transformations       Attending
# 4890  Data Visualization using Power BI       Attending
# 4891  Data Visualization using Power BI       Attending
# 4892  Data Visualization using Power BI       Attending
# 4893  Data Visualization using Power BI       Attending
#
#                                            College Name  \
# 0     D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                      AP SHAH INSTITUTE OF TECHNOLOGY
# 2          Don Bosco College of Engineering Fatorda Goa
# 3              Pillai College of Engineering New Panvel
# 4                                  St Xavier's College
# ...                                                 ...
# 4889  thakur institute of management studies, career...
# 4890                 government polytechnic gandhinagar
# 4891          vishwakarma institute of technology, pune
# 4892                 mit academy of engineering ,alandi
# 4893                 a. c. patil college of engineering
#
#            How did you come to know about this event?  \
# 0                                               Email
# 1                                              Others
# 2                                               Email
# 3                                               Email
# 4     Instagram | LinkedIn | Cloud Counselage Website
# ...                                               ...
# 4889                      LinkedIn | Whatsapp | Email
# 4890                                              NaN
# 4891                                              NaN
# 4892                                              NaN
# 4893                                              NaN
#
#      Specify in "Others" (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                               College
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4889                                                NaN
# 4890                                                NaN
# 4891                                                NaN
# 4892                                                NaN
# 4893                                                NaN
#
#      Designation  Year of Graduation       City  CGPA  \
# 0       Students                2024      Patna   6.7
# 1       Students                2024   Amravati   8.2
# 2       Students                2023    Kunrool   6.5
# 3       Students                2025   Tirupati   8.7
# 4       Students                2024  Vijaywada   9.1
# ...          ...                 ...        ...   ...
# 4889    Students                2024    Jodhpur   6.9
# 4890    Students                2023    Jalgaon   6.5
# 4891    Students                2024      Thane   6.9
# 4892    Students                2024    Patiala   9.0
# 4893    Students                2025    Sangrur   7.2
#
#       Experience with python (Months) Family Income  Expected salary (Lac)  \
# 0                                   7       7 Lakh+                      6
# 1                                   3      0-2 Lakh                      7
# 2                                   4      5-7 Lakh                      7
# 3                                   7      2-5 Lakh                      8
# 4                                   3      0-2 Lakh                     10
# ...                               ...           ...                    ...
# 4889                                6      0-2 Lakh                     15
# 4890                                6      0-2 Lakh                      8
# 4891                                5      0-2 Lakh                      7
# 4892                                3      0-2 Lakh                     23
# 4893                                8      0-2 Lakh                      9
#
#      Leadership- skills
# 0                   yes
# 1                    no
# 2                    no
# 3                    no
# 4                   yes
# ...                 ...
# 4889                yes
# 4890                 no
# 4891                 no
# 4892                yes
# 4893                yes
#
# [4894 rows x 16 columns]

# %%
data.head()
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# 1                                           Others
# 2                                            Email
# 3                                            Email
# 4  Instagram | LinkedIn | Cloud Counselage Website
#
#   Specify in "Others" (how did you come to know about this event) Designation  \
# 0                                                NaN                 Students
# 1                                            College                 Students
# 2                                                NaN                 Students
# 3                                                NaN                 Students
# 4                                                NaN                 Students
#
#    Year of Graduation       City  CGPA  Experience with python (Months)  \
# 0                2024      Patna   6.7                                7
# 1                2024   Amravati   8.2                                3
# 2                2023    Kunrool   6.5                                4
# 3                2025   Tirupati   8.7                                7
# 4                2024  Vijaywada   9.1                                3
#
#   Family Income  Expected salary (Lac) Leadership- skills
# 0       7 Lakh+                      6                yes
# 1      0-2 Lakh                      7                 no
# 2      5-7 Lakh                      7                 no
# 3      2-5 Lakh                      8                 no
# 4      0-2 Lakh                     10                yes

# %%
data.tail()
# Out:
#      First Name Email ID  Quantity                             Events  \
# 4889        NaN      NaN         1   The SDLC & their transformations
# 4890        NaN      NaN         1  Data Visualization using Power BI
# 4891        NaN      NaN         1  Data Visualization using Power BI
# 4892        NaN      NaN         1  Data Visualization using Power BI
# 4893        NaN      NaN         1  Data Visualization using Power BI
#
#      Attendee Status                                       College Name  \
# 4889       Attending  thakur institute of management studies, career...
# 4890       Attending                 government polytechnic gandhinagar
# 4891       Attending          vishwakarma institute of technology, pune
# 4892       Attending                 mit academy of engineering ,alandi
# 4893       Attending                 a. c. patil college of engineering
#
#      How did you come to know about this event?  \
# 4889                LinkedIn | Whatsapp | Email
# 4890                                        NaN
# 4891                                        NaN
# 4892                                        NaN
# 4893                                        NaN
#
#      Specify in "Others" (how did you come to know about this event)  \
# 4889                                                NaN
# 4890                                                NaN
# 4891                                                NaN
# 4892                                                NaN
# 4893                                                NaN
#
#      Designation  Year of Graduation     City  CGPA  \
# 4889    Students                2024  Jodhpur   6.9
# 4890    Students                2023  Jalgaon   6.5
# 4891    Students                2024    Thane   6.9
# 4892    Students                2024  Patiala   9.0
# 4893    Students                2025  Sangrur   7.2
#
#       Experience with python (Months) Family Income  Expected salary (Lac)  \
# 4889                                6      0-2 Lakh                     15
# 4890                                6      0-2 Lakh                      8
# 4891                                5      0-2 Lakh                      7
# 4892                                3      0-2 Lakh                     23
# 4893                                8      0-2 Lakh                      9
#
#      Leadership- skills
# 4889                yes
# 4890                 no
# 4891                 no
# 4892                yes
# 4893                yes

# %% [markdown]
# # BASIC QUESTIONS

# %% [markdown]
# # How many unique students are included in the dataset

# %%
# Assuming the dataset has a column named 'Email ID' for student identification
unique_students = data['Email ID'].nunique()

print(f"Number of unique students: {unique_students}")
# Out:
# Number of unique students: 2157

# %% [markdown]
# # What is the average GPA of the students

# %%
# Assuming the dataset has a column named 'CGPA' for GPA
average_gpa = data['CGPA'].mean()

print(f"Average GPA of the students: {average_gpa:.2f}")
# Out:
# Average GPA of the students: 8.04

# %% [markdown]
# # What is the distribution of student's across different graduation years

# %%
import matplotlib.pyplot as plt
# Assuming the dataset has a column named 'Year of Graduation' for graduation years
graduation_counts = data['Year of Graduation'].value_counts().sort_index()

# Plotting the distribution
plt.figure(figsize=(10, 6))
graduation_counts.plot(kind='bar', color='purple')
plt.title('Distribution of Students Across Graduation Years')
plt.xlabel('Graduation Year')
plt.ylabel('Number of Students')
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # What is the distribution of student's experience with python programming

# %%
# Assuming the dataset has a column named 'Experience with python (Months)' for experience levels
experience_counts = data['Experience with python (Months)'].value_counts().sort_index()

# Plotting the distribution
plt.figure(figsize=(8, 6))
experience_counts.plot(kind='bar', color='violet')
plt.title("Distribution of Students' Experience with Python Programming")
plt.xlabel('Python Experience Level')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # How does the GPA vary among different colleges (Show top 5 results only)

# %%
# Assuming the dataset has columns 'College Name' and 'CGPA'
college_gpa = data.groupby('College Name')['CGPA'].mean().sort_values(ascending=False)

# Show top 5 colleges with highest average GPA
top_colleges = college_gpa.head(5)

# Plotting the top 5 colleges and their average GPA
plt.figure(figsize=(10, 6))
top_colleges.plot(kind='bar', color='lightgreen')
plt.title('Top 5 Colleges by Average GPA')
plt.xlabel('College')
plt.ylabel('Average GPA')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Are there any outliers in the quantity (Number of courses completed) attribute

# %%
import seaborn as sns

# %%
# Assuming the dataset has a column named 'Quantity' for number of courses completed
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.boxplot(x=data['Quantity'])
plt.title('Boxplot of Quantity (Number of Courses Completed)')
plt.xlabel('Quantity')
plt.show()

# %% [markdown]
# # What is the average GPA for student from each city

# %%
# Assuming the dataset has columns 'City' and 'CGPA'
average_gpa_by_city = data.groupby('City')['CGPA'].mean()

# Print the average GPA for each city
for city, avg_gpa in average_gpa_by_city.items():
    print(f"Average GPA for students from {city}: {avg_gpa:.2f}")
# Out:
# Average GPA for students from Agartala: 7.66
# Average GPA for students from Agra: 8.05
# Average GPA for students from Ahemdabad: 8.19
# Average GPA for students from Ajmer: 8.28
# Average GPA for students from Akola: 8.02
# Average GPA for students from Aligarh: 7.83
# Average GPA for students from Alipore: 8.10
# Average GPA for students from Almora: 8.04
# Average GPA for students from Ambala: 8.02
# Average GPA for students from Ambikapur: 8.00
# Average GPA for students from Amer: 7.92
# Average GPA for students from Amravati: 7.87
# Average GPA for students from Amreli: 8.00
# Average GPA for students from Amritsar: 7.95
# Average GPA for students from Anantnag: 7.98
# Average GPA for students from Aurangabad: 8.26
# Average GPA for students from Badmi: 7.95
# Average GPA for students from Baleshwar: 8.06
# Average GPA for students from Ballari: 8.09
# Average GPA for students from Baramula: 8.09
# Average GPA for students from Barmer: 8.08
# Average GPA for students from Belgavi: 8.22
# Average GPA for students from Bengaluru: 8.05
# Average GPA for students from Bhandara: 7.91
# Average GPA for students from Bhilai: 7.78
# Average GPA for students from Bhopal: 8.17
# Average GPA for students from Bhsawal: 7.94
# Average GPA for students from Bid: 7.83
# Average GPA for students from Bidar: 7.84
# Average GPA for students from Bikaner: 7.88
# Average GPA for students from Budaun: 8.29
# Average GPA for students from Buldhana: 8.35
# Average GPA for students from Burani: 8.27
# Average GPA for students from Chamba: 7.73
# Average GPA for students from Chandigarh: 8.06
# Average GPA for students from Chapra: 8.05
# Average GPA for students from Cuttack: 8.04
# Average GPA for students from Daman: 7.42
# Average GPA for students from Darbhanga: 8.36
# Average GPA for students from Dehri: 7.85
# Average GPA for students from Delhi: 8.41
# Average GPA for students from Deoria: 7.95
# Average GPA for students from Dhar: 7.70
# Average GPA for students from Dhule: 8.04
# Average GPA for students from Diu: 8.04
# Average GPA for students from Doda: 7.69
# Average GPA for students from Durg: 7.85
# Average GPA for students from Durgapur: 7.81
# Average GPA for students from Dwarka: 8.00
# Average GPA for students from Eluru: 7.98
# Average GPA for students from Faridabad: 8.12
# Average GPA for students from Gangtok: 8.25
# Average GPA for students from Gaya: 7.96
# Average GPA for students from Ghaziabad: 7.85
# Average GPA for students from Ghazipur: 7.96
# Average GPA for students from Godhra: 7.97
# Average GPA for students from Gonda: 8.20
# Average GPA for students from Gorakhpur: 7.81
# Average GPA for students from Gulmarg: 7.92
# Average GPA for students from Guna: 8.16
# Average GPA for students from Gurugram: 8.46
# Average GPA for students from Guwahati: 8.34
# Average GPA for students from Gwalior: 7.91
# Average GPA for students from Haijipur: 8.23
# Average GPA for students from Hamirpur: 7.99
# Average GPA for students from Haora: 8.03
# Average GPA for students from Hasan: 8.39
# Average GPA for students from Hisar: 8.01
# Average GPA for students from Hugli: 8.27
# Average GPA for students from Hyderbad: 7.76
# Average GPA for students from Indore: 7.96
# Average GPA for students from Jaipur: 8.29
# Average GPA for students from Jalgaon: 8.02
# Average GPA for students from Jalor: 7.93
# Average GPA for students from Jamalpur: 8.11
# Average GPA for students from Jammu: 8.28
# Average GPA for students from Jamnagar: 8.12
# Average GPA for students from Jhalwar: 8.35
# Average GPA for students from Jhansi: 7.96
# Average GPA for students from Jind: 8.26
# Average GPA for students from Jodhpur: 7.97
# Average GPA for students from Junagadh: 7.98
# Average GPA for students from Kaithal: 7.90
# Average GPA for students from Kaithar: 7.85
# Average GPA for students from Kalyan: 8.13
# Average GPA for students from Kangra: 7.81
# Average GPA for students from Kanpur: 8.02
# Average GPA for students from Karli: 7.80
# Average GPA for students from Karnal: 7.98
# Average GPA for students from Kheda: 8.11
# Average GPA for students from Kochi: 8.03
# Average GPA for students from Kolar: 7.84
# Average GPA for students from Kolhapur: 8.56
# Average GPA for students from Kolkata: 7.83
# Average GPA for students from Kollam: 8.17
# Average GPA for students from Kota: 7.92
# Average GPA for students from Kunrool: 7.89
# Average GPA for students from Lucknow: 7.79
# Average GPA for students from Madgaon: 8.16
# Average GPA for students from Mahe: 8.04
# Average GPA for students from Mainpuri: 7.87
# Average GPA for students from Malda: 8.29
# Average GPA for students from Mandi: 8.06
# Average GPA for students from Matheran: 8.04
# Average GPA for students from Mathura: 8.07
# Average GPA for students from Morbi: 7.97
# Average GPA for students from Motihari: 7.90
# Average GPA for students from Mumbai: 8.16
# Average GPA for students from Munger: 8.31
# Average GPA for students from Muzaffarpur: 8.28
# Average GPA for students from Mysuru: 7.81
# Average GPA for students from Nadiad: 8.15
# Average GPA for students from Nagaon: 7.81
# Average GPA for students from Nagpur: 8.03
# Average GPA for students from Nanded: 8.03
# Average GPA for students from Narwar: 8.30
# Average GPA for students from Nashik: 7.59
# Average GPA for students from Navi Mumbai: 8.08
# Average GPA for students from Navsari: 7.85
# Average GPA for students from New Delhi: 7.31
# Average GPA for students from Nizambad: 8.34
# Average GPA for students from Okha: 7.92
# Average GPA for students from Orchha: 8.03
# Average GPA for students from Palashi: 7.92
# Average GPA for students from Pali: 7.99
# Average GPA for students from Panipat: 7.62
# Average GPA for students from Panji: 8.32
# Average GPA for students from Patiala: 8.09
# Average GPA for students from Patna: 7.73
# Average GPA for students from Punch: 8.26
# Average GPA for students from Pune: 8.40
# Average GPA for students from Puri: 8.45
# Average GPA for students from Raipur: 8.51
# Average GPA for students from Rajkot: 8.19
# Average GPA for students from Rajouri: 7.78
# Average GPA for students from Rewari: 7.39
# Average GPA for students from Rohtak: 7.82
# Average GPA for students from Sagar: 8.25
# Average GPA for students from Sangli: 7.96
# Average GPA for students from Sangola: 7.89
# Average GPA for students from Sangrur: 7.97
# Average GPA for students from Santipur: 7.97
# Average GPA for students from Sasaram: 7.94
# Average GPA for students from Satara: 8.16
# Average GPA for students from Satna: 7.95
# Average GPA for students from Shillong: 7.96
# Average GPA for students from Shimla: 7.91
# Average GPA for students from Sikar: 8.15
# Average GPA for students from Silguri: 8.04
# Average GPA for students from Siliguri: 7.84
# Average GPA for students from Silvassa: 7.84
# Average GPA for students from Sirsa: 8.00
# Average GPA for students from Siuri: 8.21
# Average GPA for students from Sivasagar: 7.96
# Average GPA for students from Siwan: 8.45
# Average GPA for students from Solapur: 7.71
# Average GPA for students from Sonipat: 8.46
# Average GPA for students from Srinagar: 8.44
# Average GPA for students from Surat: 8.06
# Average GPA for students from Talmuk: 8.02
# Average GPA for students from Tezpur: 8.06
# Average GPA for students from Thane: 8.05
# Average GPA for students from Thrissur: 8.03
# Average GPA for students from Tirupati: 8.21
# Average GPA for students from Titagrah: 8.06
# Average GPA for students from Udhampur: 8.06
# Average GPA for students from Ujjain: 8.06
# Average GPA for students from Ulhasnagar: 7.79
# Average GPA for students from Una: 8.25
# Average GPA for students from Valsad: 8.05
# Average GPA for students from Varanasi: 8.25
# Average GPA for students from Vasai: 7.67
# Average GPA for students from Vidisha: 7.74
# Average GPA for students from Vijaywada: 7.99
# Average GPA for students from Wardha: 8.33
# Average GPA for students from konark: 8.07
# Average GPA for students from kullu: 7.88

# %% [markdown]
# # Can we identify any relationship between family income and GPA

# %%
# Assuming the dataset has columns 'Family Income' and 'CGPA'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Family Income', y='CGPA', data=data)
plt.title('Scatter Plot of Family Income vs. GPA')
plt.xlabel('Family Income')
plt.ylabel('GPA')
plt.tight_layout()
plt.show()

# %% [markdown]
# # MODERATE QUESTIONS

# %% [markdown]
# # Which event tend to attract more students from specific fields of study

# %%
# Assuming the dataset has columns 'Events' and 'Attendee Status' for event name and student field
plt.figure(figsize=(12, 6))
sns.countplot(x='Events', hue='Attendee Status', data=data)
plt.title('Event Attendance by Student Fields')
plt.xlabel('Event Name')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Student Field')
plt.show()

# %% [markdown]
# # Do students in leadership positions during their college years tend to have higher GPAs or better expected salary

# %%
# Assuming the dataset has columns 'Leadership- skills', 'CGPA', and 'Expected salary (Lac)'
plt.figure(figsize=(12, 6))
sns.boxplot(x='Leadership- skills', y='CGPA', data=data)
plt.title('GPA vs. Leadership Position')
plt.xlabel('Leadership Position')
plt.ylabel('GPA')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Leadership- skills', y='Expected salary (Lac)', data=data)
plt.title('Expected Salary vs. Leadership Position')
plt.xlabel('Leadership Position')
plt.ylabel('Expected Salary')
plt.tight_layout()
plt.show()

# %% [markdown]
# # How many students are graduating by the end of 2024

# %%
# Assuming the dataset has a column named 'Year of Graduation' for graduation years
graduating_by_2024 = data[data['Year of Graduation'] <= 2024]
num_graduating = len(graduating_by_2024)

print(f"Number of students graduating by the end of 2024: {num_graduating}")
# Out:
# Number of students graduating by the end of 2024: 3047

# %% [markdown]
# # How many students know about the event from their colleges (Which of these Top 5 colleges)

# %%
# Assuming 'College' is the column containing college names and 'Knows About Event' is the column indicating if they know about the event
# You might need to adjust column names based on your data
top_5_colleges = data['College Name'].value_counts().head(5)

print("Top 5 Colleges and the Number of Students Who Know About the Event:")
print(top_5_colleges)
# Out:
# Top 5 Colleges and the Number of Students Who Know About the Event:
# priyadarshini college of engineering, nagpur                            261
# vidyalankar institute of technology, mumbai                             258
# ld college of engineering, ahmedabad, gujarat                           248
# government polytechnic gandhinagar                                      206
# b. k. birla college of arts, science & commerce (autonomous), kalyan    206
# Name: College Name, dtype: int64

# %% [markdown]
# # How does the expected salary vary based on factors like 'GPA', 'Famliy income', 'Experience with Python(Months)'

# %%
print(data.dtypes)
# Out:
# First Name                                                          object
# Email ID                                                            object
# Quantity                                                             int64
# Events                                                              object
# Attendee Status                                                     object
# College Name                                                        object
# How did you come to know about this event?                          object
# Specify in "Others" (how did you come to know about this event)     object
# Designation                                                         object
# Year of Graduation                                                   int64
# City                                                                object
# CGPA                                                               float64
# Experience with python (Months)                                      int64
# Family Income                                                       object
# Expected salary (Lac)                                                int64
# Leadership- skills                                                  object
# dtype: object

# %%
print(data['Family Income'].dtype)
# Out:
# object

# %%
data['Family Income'] = pd.to_numeric(data['Family Income'], errors='coerce')

# %%
# Assuming 'data' is your DataFrame
data['Family Income'] = pd.to_numeric(data['Family Income'], errors='coerce')

# Now, try your mathematical operation again
result = data['Family Income'] * 2  

# Check the result or perform your intended operation
print(result)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4889   NaN
# 4890   NaN
# 4891   NaN
# 4892   NaN
# 4893   NaN
# Name: Family Income, Length: 4894, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# # Create a pairplot to visualize relationships among variables
sns.pairplot(data, x_vars=['CGPA', 'Experience with python (Months)', 'Family Income'], y_vars=['Expected salary (Lac)'], kind='reg')
plt.show()

# %% [markdown]
# # Find the total number of students who attended the events related to data science (From all data science related courses)

# %%
data = {
    'Email ID': ['george@xyz.com', 'cynthia@xyz.com', 'theodore@xyz.com', 'martha@xyz.com', 'chauncey@xyz.com'],
    'Events': ['Data Visualization using Power BI', 'Artificial Intelligence', 'Hello ML and DL', 'Product Marketing', 'IAC - Q&A'],
    'Attendee Status': [True, False, True, True, True]
}

# Create a DataFrame
data = pd.DataFrame(data)

# Filter for Data Science-related courses and event attendance
data_science_courses = ['Data Visualization using Power BI', 'Artificial Intelligence']
filtered_data = data[(data['Events'].isin(data_science_courses)) & (data['Attendee Status'] == True)]

# Calculate the total number of students who attended data science events
total_attendees = filtered_data['Email ID'].nunique()

print(f'Total number of students who attended data science events: {total_attendees}')
# Out:
# Total number of students who attended data science events: 1

# %% [markdown]
# # Those who have CGPA and More experience in language those who had high expectations for salary (Avg)

# %%
# Assuming 'CGPA', 'Experience with python (Months)', and 'Expected salary (Lac)' are the relevant columns
filtered_data = data[(data['CGPA'] >= 9.0) & (data['Experience with python (Months)'] > 6)]

high_salary_expectations = filtered_data[filtered_data['Expected salary (Lac)'] > filtered_data['Expected salary (Lac)'].mean()]

print(f"The number of students with high CGPA and more experience in language, and high salary expectations is: {len(high_salary_expectations)}")
# Out:
# The number of students with high CGPA and more experience in language, and high salary expectations is: 173

# %% [markdown]
# # Which promotion channel is brings in more student participations for the event

# %%
# Assuming 'How did you come to know about this event?' and 'Attendee Status' are the relevant columns
channel_attendance = data.groupby('How did you come to know about this event?')['Quantity'].sum()

# Find the promotion channel with the highest attendance
most_successful_channel = channel_attendance.idxmax()
max_attendance = channel_attendance.max()

print(f"The most successful promotion channel is '{most_successful_channel}' with a total attendance of {max_attendance} students.")

# Plotting the attendance by promotion channel
plt.figure(figsize=(30,12))
channel_attendance.sort_values(ascending=False).plot(kind='bar')
plt.xlabel('How did you come to know about this event?')
plt.ylabel('Total Attendance')
plt.title('Attendance by Promotion Channel')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# The most successful promotion channel is 'Whatsapp' with a total attendance of 1067 students.

# %% [markdown]
# # Ploting the most succesful promotions channel is whatsapp with a total attedance of 1067 students for better understanding

# %%
# Data
channel = 'Whatsapp'
total_attendance = 1067

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(channel, total_attendance, color='skyblue')
plt.xlabel('Promotion Channel')
plt.ylabel('Total Attendance')
plt.title('Most Successful Promotion Channel')
plt.text(channel, total_attendance + 20, str(total_attendance), ha='center', va='bottom', fontsize=12, color='black')
plt.tight_layout()

plt.show()
